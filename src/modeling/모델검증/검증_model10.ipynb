# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install mxnet
# !pip install gluonnlp pandas tqdm
# !pip install sentencepiece
# !pip install transformers==3 # 최신 버전으로 설치하면 "Input: must be Tensor, not str" 라는 에러 발생
# !pip install torch
# !pip install torchmetrics

# !pip install git+https://git@github.com/SKTBrain/KoBERT.git@master
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://****@github.com/SKTBrain/KoBERT.git (to revision master) to /tmp/pip-req-build-upvk7qyq
#   Running command git clone -q 'https://****@github.com/SKTBrain/KoBERT.git' /tmp/pip-req-build-upvk7qyq
# ...
#      |████████████████████████████████| 129 kB 32.1 MB/s
# ...
#      |████████████████████████████████| 344 kB 86.5 MB/s
# ...
#      |████████████████████████████████| 54.7 MB 80.3 MB/s
# ...
#      |████████████████████████████████| 4.5 MB 85.5 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 80.1 MB/s
# ...

# %%
# gpu 프리미엄 사용 시
# !pip3 install torch==1.9.0+cu111 torchvision==0.10.0+cu111 torchaudio==0.9.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |█████████████                   | 834.1 MB 112.0 MB/s eta 0:00:11tcmalloc: large alloc 1147494400 bytes == 0x3a9b2000 @  0x7f0cd0019615 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x4fd8b5 0x4997c7 0x4fd8b5 0x49abe4 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x5d8868 0x5da092 0x587116 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x4990ca 0x5d8868 0x4997a2 0x4fd8b5 0x49abe4
#      |██████████████▋                 | 929.0 MB 134.3 MB/s eta 0:00:09
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ...

# %%
import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import gluonnlp as nlp
import numpy as np
from tqdm import tqdm, tqdm_notebook

from sklearn.model_selection import train_test_split

from kobert.utils import get_tokenizer
from kobert.pytorch_kobert import get_pytorch_kobert_model

from transformers import AdamW
from transformers.optimization import get_cosine_schedule_with_warmup
import pandas as pd
from tqdm.notebook import tqdm

import re

# %%
##GPU 사용 시
device = torch.device("cuda:0")

bertmodel, vocab = get_pytorch_kobert_model()

from transformers import AutoTokenizer, AutoModelForSequenceClassification

# tokenizer = AutoTokenizer.from_pretrained("snunlp/KR-FinBert-SC")

# model = AutoModelForSequenceClassification.from_pretrained("snunlp/KR-FinBert-SC")
# Out:
# /content/.cache/kobert_v1.zip[██████████████████████████████████████████████████]
# /content/.cache/kobert_news_wiki_ko_cased-1087f8699e.spiece[██████████████████████████████████████████████████]

# %% [markdown]
# ### 데이터 전처리

# %%
import pandas as pd

# %% [markdown]
# # 데이터 입력

# %%
df_sent = pd.read_csv('/content/drive/MyDrive/뉴스원인분석_modeling/data/lgenergy_sent_labeled_0103.csv')
df_sent
# Out:
#               date                                               sent  label  \
# 0       2022-01-28  증시자금 블랙홀 엔솔에 코스피 시총 69조원 증발서울연합뉴스 이미령 기자  공모주 ...      0
# 1       2022-01-28  27일 한국거래소에 따르면 이날 유가증권시장 시가총액은 총 2천56조8천억원으로 전...      0
# 2       2022-01-28  다만 이는 이날 상장한 에너지솔루션 시가총액118조2천억원이 더해진 규모로, 에너지...      0
# 3       2022-01-28    이날 코스피가 3.50 급락하며 2,610대로 밀려난 것도 이런 이유에서란 분석이다.      0
# 4       2022-01-28  서상영 미래에셋증권 연구원은 이날 코스피 하락 요인 중 가장 큰 건 에너지솔루션 수...      0
# ...            ...                                                ...    ...
# 125904  2022-11-30                        업계에서는 분할 공포증 영향이라는 해석도 나온다.      4
# 125905  2022-11-30  화학의 에너지솔루션 물적 분할 이후 분할악재라는 인식 때문에 주가가 내리는 것이라는...      4
# 125906  2022-11-30  한 투자 업계 고위 임원은 기존 사업이 돈을 벌고 신사업에 투자하다 신사업이 자생력...      4
# 125907  2022-11-30  다만 주가가 지나치게 급락했다는 점에서 외부로 알려지지 않은 내용이 더 있는 것 아...      4
# 125908  2022-11-30  한 투자 업계 관계자는 주가가 급락하는 배경이 있을 수도 있다며 장 상황이 안 좋다...      4
#
#         news_id  targetpm
# ...

# %%
# 셔플
df_sent = df_sent.sample(frac=1).reset_index(drop=True)
df_sent
# Out:
#               date                                               sent  label  \
# 0       2022-07-15           전날 대만 의 2분기 호실적 발표가 긍정적 영향을 끼친 것으로 분석된다.      2
# 1       2022-07-27  유가증권시장과 코스닥시장 하루 거래대금은 각각 6조8천897억원, 5조511억원 수...      2
# 2       2022-05-06             여기에 기관투자자 역시 배정된 공모주의 1에 해당하는 수수료를 낸다.      2
# 3       2022-02-15  그나마도 하이닉스가 강보합 수준의 상승폭을 기록한 것을 감안하면 시총 10위까지의 ...      1
# 4       2022-03-14  코스닥시장에선 개인이 홀로 2574억 원을 사들이는 한편 외국인과 기관은 각각 21...      0
# ...            ...                                                ...    ...
# 125904  2022-02-25  투자일임업 등록일로부터 2년이 지나고, 수요예측 참여일 직전 영업일 기준으로 투자일...      2
# 125905  2022-03-02  지수는 2698.31로 하락 출발한 뒤 2690선에서 등락을 거듭했으나 오후 들어 ...      4
# 125906  2022-06-15  종이목재가 5.26 하락했고, 서비스업3.85, 기계3.23, 증권2.55, 의료정...      1
# 125907  2022-04-01                      2024년까지 생산능력을 5만톤 까지 틀릴 계획이다.      0
# 125908  2022-03-15  리튬인산철 배터리를 앞세운 중국 업체의 도전이 거센 데다 노스볼트orthvolt 등...      1
#
#         news_id  targetpm
# ...

# %%
df_gr = df_sent.groupby('date')[['label']].mean()
# 날짜별로 train_test_split
train_date, test_date = train_test_split(df_gr, test_size=0.1, random_state=2022, stratify=df_gr['label'])
train_date_list = train_date.index
test_date_list = test_date.index
train_data = df_sent[df_sent['date'].isin(train_date_list)][['date','sent', 'label','targetpm','news_id']]
test_data = df_sent[df_sent['date'].isin(test_date_list)][['date','sent', 'label','targetpm','news_id']]
train_data.shape, test_data.shape
# Out:
# ((113514, 5), (12395, 5))

# %%
df_sent['label'].value_counts()
# Out:
# 2    36903
# 3    31596
# 1    27166
# 0    15296
# 4    14948
# Name: label, dtype: int64

# %%
tokenizer = get_tokenizer()
tok = nlp.data.BERTSPTokenizer(tokenizer, vocab, lower=False)
# Out:
# using cached model. /content/.cache/kobert_news_wiki_ko_cased-1087f8699e.spiece

# %%
class BERTDataset(Dataset):
    def __init__(self, dataset, sent_idx, label_idx, bert_tokenizer, max_len,
                 pad, pair):
        transform = nlp.data.BERTSentenceTransform(
            bert_tokenizer, max_seq_length=max_len, pad=pad, pair=pair) 

        self.sentences = [transform([i[sent_idx]]) for i in dataset]
        self.labels = [np.int32(i[label_idx]) for i in dataset]

    def __getitem__(self, i):
        return (self.sentences[i] + (self.labels[i], ))

    def __len__(self):
        return (len(self.labels))

# %%
max_len = 128 # 해당 길이를 초과하는 단어에 대해선 bert가 학습하지 않음
batch_size = 64
warmup_ratio = 0.1
num_epochs = 50
max_grad_norm = 1
log_interval = 200
learning_rate = 5e-5

# %%
data_train = BERTDataset(train_data_list, 0, 1, tok, max_len, True, False)
data_test = BERTDataset(test_data_list, 0, 1, tok, max_len, True, False)

# %%
# pytorch용 DataLoader 사용
train_dataloader = torch.utils.data.DataLoader(data_train, batch_size=batch_size, num_workers=5)
test_dataloader = torch.utils.data.DataLoader(data_test, batch_size=batch_size, num_workers=5)

# %%
class BERTClassifier(nn.Module):
    def __init__(self,
                 bert,
                 hidden_size = 768,
                 num_classes = 5, # softmax 사용 <- binary일 경우는 2
                 dr_rate=None,
                 params=None):
        super(BERTClassifier, self).__init__()
        self.bert = bert
        self.dr_rate = dr_rate
                 
        self.classifier = nn.Linear(hidden_size , num_classes)
        if dr_rate:
            self.dropout = nn.Dropout(p=dr_rate)
    
    def gen_attention_mask(self, token_ids, valid_length):
        attention_mask = torch.zeros_like(token_ids)
        for i, v in enumerate(valid_length):
            attention_mask[i][:v] = 1
        return attention_mask.float()

    def forward(self, token_ids, valid_length, segment_ids):
        attention_mask = self.gen_attention_mask(token_ids, valid_length)
        
        _, pooler = self.bert(input_ids = token_ids, token_type_ids = segment_ids.long(), attention_mask = attention_mask.float().to(token_ids.device))
        if self.dr_rate:
            out = self.dropout(pooler)
        return self.classifier(out)

# %%
model = BERTClassifier(bertmodel,  dr_rate=0.5).to(device)

# %%
# 학습 평가 지표인 accuracy 계산 -> 얼마나 타겟값을 많이 맞추었는가
def calc_accuracy(X,Y):
    max_vals, max_indices = torch.max(X, 1)
    train_acc = (max_indices == Y).sum().data.cpu().numpy()/max_indices.size()[0]
    return train_acc

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
model = torch.load("/content/drive/MyDrive/뉴스원인분석_modeling/model/KoBERT_lgenergy_model_mxl128_bt128_sentmodel1229.pt")
model.eval()
# Out:
# BERTClassifier(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(8002, 768, padding_idx=1)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
# ...

# %%
test_data
# Out:
#               date                                               sent  label  \
# 9       2022-07-27           업계는 반도체 분야에서 그룹의 미국 내 신규 투자 발표 여부에 주목했다.      2
# 12      2022-10-05  이에 따라 공모 금액은 기존 225억280억원에서 137억원으로, 예상 시가총액은 ...      4
# 36      2022-07-27                            개인도 이달 2962억원 매도로 전환했다.      2
# 62      2022-02-16  김지산 키움증권 연구원은 지난해 차량용 반도체 공급난에도 전기차 시장은 중국 주도로...      3
# 72      2022-07-29       또 금지일에 주가하락률이 5 이상일때는 금지기간을 다음날까지 자동으로 연장한다.      3
# ...            ...                                                ...    ...
# 125847  2022-03-17                                      4일에 1번꼴로 바뀌었다      4
# 125850  2022-04-07        같은 기간 매출액은 전년 동기 대비 2.1 증가한 4조3423억원을 달성했다.      1
# 125859  2022-08-01              삼성삼성과  n는 2차전지사업도 그룹의 주력 사업으로 키우고 있다.      2
# 125868  2022-08-19            이외에 테네시주, 미시간주에서도 각각 제2, 제3 공장을 건설 중이다.      1
# 125883  2022-04-07  서상영 미래에셋증권 연구원은 최근 시장의 화두인 높은 물가를 감안해 연준이 생각보다...      1
#
#         targetpm
# 9              1
# ...

# %%
# batch_size 수정 코드
batch_size = 128

test_data3 = test_data.copy()
test_data3 = test_data3.reset_index(drop=True )
test_data3['pred'] = ''

model.eval()
unseen_values = test_data3[['sent', 'label']].values
test_set = BERTDataset(unseen_values, 0, 1, tok, max_len, True, False)
test_input = torch.utils.data.DataLoader(test_set, batch_size=batch_size, num_workers=5)
for batch_id, (token_ids, valid_length, segment_ids, label) in tqdm(enumerate(test_input)):
  token_ids = token_ids.long().to(device)
  segment_ids = segment_ids.long().to(device)
  valid_length= valid_length
  out = model(token_ids, valid_length, segment_ids)
  for outn in range(len(out)) :
    pred = int(out[outn].argmax().cpu().numpy())
    idx = batch_size * batch_id + outn
    test_data3.iloc[idx, -1] = pred
    if idx % 5000 == 0 :
      print(idx, pred)
test_data3.head(20)
# Out:
# 0it [00:00, ?it/s]
# 0 0
# 5000 1
# 10000 2
#           date                                               sent  label  \
# 0   2022-07-27  유가증권시장과 코스닥시장 하루 거래대금은 각각 6조8천897억원, 5조511억원 수...      2
# 1   2022-08-16  정 팀장은 6월 글로벌 증시가 모두 바닥을 확인했기 때문에 하방이 매우 튼튼하지만 ...      2
# 2   2022-04-07  이 대표는 그러면서 그래서 저희는 거기분당에 이 지사가 출마하기를 고대하고 있다고 ...      1
# 3   2022-08-16  시총 가장 많이 늘린 신학철최준영송호성국내 주요 상장 기업 대표이사 중 취임 후 시...      2
# 4   2022-08-01                              같은 기간 재고자산도 급증하는 추세다.      2
# 5   2022-05-04  코스닥 시가총액 상위 10개 종목 중에서는 셀트리온제약2.11, 셀트리온헬스케어1....      1
# 6   2022-04-07  한국투자증권은 완성차 업체들은 배터리 가격이 2030년까지 4056까지 낮아질 것으...      1
# 7   2022-06-30  올해 상장한 30개 종목코넥스 2개 제외의 최종 공모가를 확인한 결과 희망공모가의 ...      0
# 8   2022-06-30  증권가는 30일현지시간 발표되는 5월 미국 개인소비지출 물가 지수 발표를 앞두고 시...      0
# 9   2022-07-27  서울산업대학교에서 기계공학을 전공한 오 대표는 스프에이시스템코리아, 삼우엔지니어링,...      2
# 10  2022-04-07  코스닥 시가총액 상위 10위권은 엘앤에프0.39, 펄어비스0.10를 제외하고는 모두...      1
# ...

# %%
# 뉴스별 라벨링
# 뉴스 빈도 + 날 빈도
test_data4 = test_data.copy()
test_data4['pred'] = test_data3['pred'].values 
test_data4['pred'] = test_data4['pred'].astype('int')
df_news = test_data4.groupby('news_id')[['label', 'pred', 'targetpm']].mean()
df_news_idx = df_news.index
# 뉴스 라벨 빈도수 계산
for idx in df_news_idx:
  df_news.loc[idx, 'cnt_pred'] = int(test_data4[test_data4['news_id'] == idx ]['pred'].value_counts().idxmax())
  # print(idx, df_news.loc[idx, 'cnt_pred'])
  
# 뉴스별 값 태깅
test_data4['news_cnt'] = -1
for idx_nm in range(len(test_data4)) :
  news_idx = test_data4.iloc[idx_nm, 4]
  test_data4.iloc[idx_nm, -1] = df_news.loc[news_idx, 'cnt_pred']

df_gr = test_data4.groupby('date')[['label', 'news_cnt', 'targetpm']].mean()
df_date = df_gr.index
for idx in df_date:
  df_gr.loc[idx, 'cnt_pred'] = int(test_data4[test_data4['date'] == idx ]['news_cnt'].value_counts().idxmax())

df_gr['pred_label'] = df_gr['cnt_pred'].apply(lambda x : int(np.round(x)))
df_gr['pred_pm'] = df_gr['pred_label'].apply(lambda x: 1 if x< 2 else 3)




df_gr = df_gr.reset_index()
for idx in df_gr.index :
  if df_gr.loc[idx, 'label'] == df_gr.loc[idx, 'pred_label']:
    temp_eval = True
  else :
    temp_eval = False
  df_gr.loc[idx, 'eval_5'] = temp_eval

for idx in df_gr.index :
  if df_gr.loc[idx, 'label'] == 0 :
    df_gr.loc[idx, 'target_3label'] = 1
  elif df_gr.loc[idx, 'label'] == 4 :
    df_gr.loc[idx, 'target_3label'] = 3
  else :
    df_gr.loc[idx, 'target_3label'] = int(df_gr.loc[idx, 'label'])

  if df_gr.loc[idx, 'pred_label'] == 0 :
    df_gr.loc[idx, 'pred_label_3label'] = 1
  elif df_gr.loc[idx, 'pred_label'] == 4 :
    df_gr.loc[idx, 'pred_label_3label'] = 3
  else :
    df_gr.loc[idx, 'pred_label_3label'] = int(df_gr.loc[idx, 'pred_label'])

df_gr['pred_label_3label'] = df_gr['pred_label_3label'].apply(lambda x : int(x))

for idx in df_gr.index :
  if df_gr.loc[idx, 'target_3label'] == df_gr.loc[idx, 'pred_label_3label']:
    temp_eval = True
  else :
    temp_eval = False
  df_gr.loc[idx, 'eval_3'] = temp_eval

for idx in df_gr.index :
  if df_gr.loc[idx, 'targetpm'] == df_gr.loc[idx, 'pred_pm']:
    temp_eval = True
  else :
    temp_eval = False
  df_gr.loc[idx, 'eval_pm'] = temp_eval



print('5중분류 정확도 :', round(df_gr['eval_5'].sum() / len(df_gr), 2), '\n')
print('3중분류 정확도 :', round(df_gr['eval_3'].sum() / len(df_gr), 2), '\n')
print('이진분류 정확도 :', round(df_gr['eval_pm'].sum() / len(df_gr), 2), '\n')

df_gr.head()
# Out:
# 5중분류 정확도 : 0.29
#
# 3중분류 정확도 : 0.33
#
# 이진분류 정확도 : 0.62
#          date  label  news_cnt  targetpm  cnt_pred  pred_label  pred_pm  \
# 0  2022-02-16    3.0  2.041379       3.0       2.0           2        3
# 1  2022-03-17    4.0  2.544803       3.0       3.0           3        3
# 2  2022-03-22    3.0  2.345850       3.0       2.0           2        3
# 3  2022-03-30    2.0  2.688995       1.0       3.0           3        3
# 4  2022-04-07    1.0  1.706362       1.0       2.0           2        3
#
#   eval_5  target_3label  pred_label_3label eval_3 eval_pm
# 0  False            3.0                  2  False    True
# 1  False            3.0                  3   True    True
# 2  False            3.0                  2  False    True
# 3  False            2.0                  3  False   False
# 4  False            1.0                  2  False   False

# %%
test_data3['pred'].value_counts()
# Out:
# 2    3964
# 3    3289
# 1    2668
# 4    1291
# 0    1183
# Name: pred, dtype: int64

# %%
df_news['cnt_pred'].value_counts()
# Out:
# 2.0    217
# 3.0    187
# 1.0    115
# 4.0     38
# 0.0     34
# Name: cnt_pred, dtype: int64

# %%
# 뉴스 거쳐가기
test_data
# Out:
#               date                                               sent  label  \
# 6       2022-08-16  코스닥 시총 상위권에서는 0.64, 1.73, 2.64, 0.56, 3.61 등 상...      2
# 16      2022-03-17                            와 이 각각 6.44, 6.33 급등했다.      4
# 19      2022-08-19  상반기 전자의 인건비는 4조9205억원으로, 임금인상 등의 영향으로 작년 동기보다 ...      1
# 24      2022-05-04                                  62개 종목은 보합에 머물렀다.      1
# 26      2022-11-29  코스피, 기관 사자에 상승 전환삼성전자 6만전자 공방전이데일리 양지윤 기자 코스피지...      3
# ...            ...                                                ...    ...
# 125882  2022-07-27               에너지솔루션1.52도 보호예수 물량 해제 영향으로 하락하고 있다.      2
# 125888  2022-08-19  포스코케미칼을 통해 이들 배터리 업체에 양극재를 공급해야 하는 포스코그룹으로서는 코...      1
# 125893  2022-06-30  코스피, 파월 물가 안정 발언에 2,400선 아래서 하락 출발상보서울연합인포맥스 윤...      0
# 125903  2022-06-30         올해 2분기 착공 예정이었고, 2024년 하반기 양산을 목표로 하고 있었다.      0
# 125906  2022-07-21  삼성에 비해 후발주자로 분류되는데 이를 만회하기 위해 공격적인 투자를 집행한 결과로...      3
#
#         targetpm
# 6              3
# ...

# %%
#표준화 후 예측
test_data4 = test_data.copy()
test_data4['pred'] = test_data3['pred'].values 
test_data4['pred'] = test_data4['pred'].astype('int')
df_gr = test_data4.groupby('date')[['label', 'pred', 'targetpm']].mean()
df_gr['count'] = test_data4.groupby('date')[['label', 'pred']].count()['label']

df_gr['target'] = df_gr['label'].apply(lambda x : int(np.round(x)))
df_gr['standard']=(df_gr['pred']-np.mean(df_gr['pred']))/np.std(df_gr['pred'])
df_gr['pred_label'] = df_gr['standard'].apply(lambda x: 0 if x<-1 else
                                                                    1 if x<-0.25 else
                                                                    2 if x<0.25 else
                                                                    3 if x<1 else
                                                                    4 )

df_gr['pred_pm'] = df_gr['pred_label'].apply(lambda x: 1 if x< 0 else 3)

# pre_mean = 2 - df_gr['pred'].median()


df_gr = df_gr.reset_index()
for idx in df_gr.index :
  if df_gr.loc[idx, 'target'] == df_gr.loc[idx, 'pred_label']:
    temp_eval = True
  else :
    temp_eval = False
  df_gr.loc[idx, 'eval_5'] = temp_eval

for idx in df_gr.index :
  # if df_gr.loc[idx, 'target'] == -2 :
  #   df_gr.loc[idx, 'target_3label'] = -1
  # elif df_gr.loc[idx, 'target'] == 2 :
  #   df_gr.loc[idx, 'target_3label'] = 1

  if df_gr.loc[idx, 'pred_label'] == 0 :
    df_gr.loc[idx, 'pred_label_3label'] = 1
  elif df_gr.loc[idx, 'pred_label'] == 4 :
    df_gr.loc[idx, 'pred_label_3label'] = 3
  else :
    df_gr.loc[idx, 'pred_label_3label'] = int(df_gr.loc[idx, 'pred_label'])

df_gr['pred_label_3label'] = df_gr['pred_label_3label'].apply(lambda x : int(x))

for idx in df_gr.index :
  if df_gr.loc[idx, 'target'] == df_gr.loc[idx, 'pred_label_3label']:
    temp_eval = True
  else :
    temp_eval = False
  df_gr.loc[idx, 'eval_3'] = temp_eval

for idx in df_gr.index :
  if df_gr.loc[idx, 'targetpm'] == df_gr.loc[idx, 'pred_pm']:
    temp_eval = True
  else :
    temp_eval = False
  df_gr.loc[idx, 'eval_pm'] = temp_eval



print('5중분류 정확도 :', round(df_gr['eval_5'].sum() / len(df_gr), 2), '\n')
print('3중분류 정확도 :', round(df_gr['eval_3'].sum() / len(df_gr), 2), '\n')
print('이진분류 정확도 :', round(df_gr['eval_pm'].sum() / len(df_gr), 2), '\n')

# for nm in np.arange(-1, 1, 0.1) :
#   df_gr['pred_mean_temp'] = (df_gr['pred'] + nm).apply(lambda x : 3 if x >= 2 else 1)
#   for idx in df_gr.index :
#     if df_gr.loc[idx, 'targetpm'] == df_gr.loc[idx, 'pred_mean_temp']:
#       temp_eval = True
#     else :
#       temp_eval = False
#     df_gr.loc[idx, 'eval_pm_mean_temp'] = temp_eval
#   print('이진분류 보정 정확도 :', '보정치:', round(nm, 1) , round(df_gr['eval_pm_mean_temp'].sum() / len(df_gr), 2), '\n')
df_gr.head()
# Out:
# 5중분류 정확도 : 0.33
#
# 3중분류 정확도 : 0.38
#
# 이진분류 정확도 : 0.57
#          date  label      pred  targetpm  count  target  standard  pred_label  \
# 0  2022-02-16    3.0  1.918621       3.0    725       3 -0.936625           1
# 1  2022-03-17    4.0  2.267622       3.0    837       4  1.171510           4
# 2  2022-03-22    3.0  2.075099       3.0    506       3  0.008577           2
# 3  2022-03-30    2.0  2.208134       1.0    418       2  0.812172           3
# 4  2022-04-07    1.0  1.729201       1.0    613       1 -2.080811           0
#
#    pred_pm eval_5  pred_label_3label eval_3 eval_pm
# 0        3  False                  1  False    True
# 1        3   True                  3  False    True
# 2        3  False                  2  False    True
# 3        3  False                  3  False   False
# 4        3  False                  1   True   False

# %%
test_data4 = test_data.copy()
test_data4['pred'] = test_data3['pred'].values 
test_data4['pred'] = test_data4['pred'].astype('int')
df_gr = test_data4.groupby('date')[['label', 'pred', 'targetpm']].mean()
df_gr['count'] = test_data4.groupby('date')[['label', 'pred']].count()['label']
df_gr['pred_label'] = df_gr['pred'].apply(lambda x : int(np.round(x)))
df_gr['pred_pm'] = df_gr['pred'].apply(lambda x : 3 if x >= 2 else 1)
df_gr['target'] = df_gr['label'].apply(lambda x : int(np.round(x)))
pre_mean = 2 - df_gr['pred'].mean()
df_gr['pred_mean'] = (df_gr['pred'] + pre_mean).apply(lambda x : 3 if x >= 2 else 1)

df_gr = df_gr.reset_index()
for idx in df_gr.index :
  if df_gr.loc[idx, 'target'] == df_gr.loc[idx, 'pred_label']:
    temp_eval = True
  else :
    temp_eval = False
  df_gr.loc[idx, 'eval_5'] = temp_eval

for idx in df_gr.index :
  # if df_gr.loc[idx, 'target'] == -2 :
  #   df_gr.loc[idx, 'target_3label'] = -1
  # elif df_gr.loc[idx, 'target'] == 2 :
  #   df_gr.loc[idx, 'target_3label'] = 1

  if df_gr.loc[idx, 'pred_label'] == 0 :
    df_gr.loc[idx, 'pred_label_3label'] = 1
  elif df_gr.loc[idx, 'pred_label'] == 4 :
    df_gr.loc[idx, 'pred_label_3label'] = 3
  else :
    df_gr.loc[idx, 'pred_label_3label'] = int(df_gr.loc[idx, 'pred_label'])

df_gr['pred_label_3label'] = df_gr['pred_label_3label'].apply(lambda x : int(x))

for idx in df_gr.index :
  if df_gr.loc[idx, 'target'] == df_gr.loc[idx, 'pred_label_3label']:
    temp_eval = True
  else :
    temp_eval = False
  df_gr.loc[idx, 'eval_3'] = temp_eval

for idx in df_gr.index :
  if df_gr.loc[idx, 'targetpm'] == df_gr.loc[idx, 'pred_pm']:
    temp_eval = True
  else :
    temp_eval = False
  df_gr.loc[idx, 'eval_pm'] = temp_eval

for idx in df_gr.index :
  if df_gr.loc[idx, 'targetpm'] == df_gr.loc[idx, 'pred_mean']:
    temp_eval = True
  else :
    temp_eval = False
  df_gr.loc[idx, 'eval_pm_mean'] = temp_eval

print('5중분류 정확도 :', round(df_gr['eval_5'].sum() / len(df_gr), 2), '\n')
print('3중분류 정확도 :', round(df_gr['eval_3'].sum() / len(df_gr), 2), '\n')
print('이진분류 정확도 :', round(df_gr['eval_pm'].sum() / len(df_gr), 2), '\n')

for nm in np.arange(-1, 1, 0.1) :
  df_gr['pred_mean_temp'] = (df_gr['pred'] + nm).apply(lambda x : 3 if x >= 2 else 1)
  for idx in df_gr.index :
    if df_gr.loc[idx, 'targetpm'] == df_gr.loc[idx, 'pred_mean_temp']:
      temp_eval = True
    else :
      temp_eval = False
    df_gr.loc[idx, 'eval_pm_mean_temp'] = temp_eval
  print('이진분류 보정 정확도 :', '보정치:', round(nm, 1) , round(df_gr['eval_pm_mean_temp'].sum() / len(df_gr), 2), '\n')

df_gr.head()
# Out:
# 5중분류 정확도 : 0.33
#
# 3중분류 정확도 : 0.33
#
# 이진분류 정확도 : 0.71
#
# 이진분류 보정 정확도 : 보정치: -1.0 0.43
#
# 이진분류 보정 정확도 : 보정치: -0.9 0.43
#
# 이진분류 보정 정확도 : 보정치: -0.8 0.43
#
# 이진분류 보정 정확도 : 보정치: -0.7 0.43
#
# 이진분류 보정 정확도 : 보정치: -0.6 0.43
#
# 이진분류 보정 정확도 : 보정치: -0.5 0.43
#
# 이진분류 보정 정확도 : 보정치: -0.4 0.43
#
# 이진분류 보정 정확도 : 보정치: -0.3 0.52
#
# 이진분류 보정 정확도 : 보정치: -0.2 0.57
#
# 이진분류 보정 정확도 : 보정치: -0.1 0.67
#
# 이진분류 보정 정확도 : 보정치: -0.0 0.71
#
# 이진분류 보정 정확도 : 보정치: 0.1 0.62
#
# 이진분류 보정 정확도 : 보정치: 0.2 0.62
#
# 이진분류 보정 정확도 : 보정치: 0.3 0.57
#
# 이진분류 보정 정확도 : 보정치: 0.4 0.57
#
# 이진분류 보정 정확도 : 보정치: 0.5 0.57
#
# 이진분류 보정 정확도 : 보정치: 0.6 0.57
#
# 이진분류 보정 정확도 : 보정치: 0.7 0.57
#
# 이진분류 보정 정확도 : 보정치: 0.8 0.57
#
# 이진분류 보정 정확도 : 보정치: 0.9 0.57
#          date  label      pred  targetpm  count  pred_label  pred_pm  target  \
# 0  2022-02-16    3.0  1.918621       3.0    725           2        1       3
# 1  2022-03-17    4.0  2.267622       3.0    837           2        3       4
# ...

# %%
df_gr['eval_pm']
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10     True
# 11    False
# 12     True
# 13    False
# 14     True
# 15     True
# 16     True
# 17     True
# 18    False
# 19     True
# 20     True
# Name: eval_pm, dtype: object

# %%
df_gr['targetpm'].value_counts()
# Out:
# 3.0    12
# 1.0     9
# Name: targetpm, dtype: int64

# %%
df_gr['pred_pm'].value_counts()
# Out:
# 3    14
# 1     7
# Name: pred_pm, dtype: int64

# %%
df_gr['eval_pm'].value_counts()
# Out:
# True     15
# False     6
# Name: eval_pm, dtype: int64

# %%
df_gr['pred_label'].value_counts()
# Out:
# 2    21
# Name: pred_label, dtype: int64

# %%
df_gr
# Out:
#            date  target      pred  count  pred_label eval_5  \
# 0    2017-12-12       3  2.454545     22           2  False
# 1    2018-01-12       1  2.250000      8           2  False
# 2    2018-01-31       3  2.190476     21           2  False
# 3    2018-04-20       2  2.235294     17           2   True
# 4    2018-05-04       2  2.166667     12           2   True
# ..          ...     ...       ...    ...         ...    ...
# 112  2022-05-30       3  2.444444     45           2  False
# 113  2022-06-30       3  2.588235     34           3   True
# 114  2022-07-13       3  2.421053     19           2  False
# 115  2022-08-04       2  2.333333     18           2   True
# 116  2022-08-09       2  2.500000     28           2   True
#
#      pred_label_3label eval_3
# 0                    2  False
# 1                    2  False
# 2                    2  False
# 3                    2   True
# 4                    2   True
# ..                 ...    ...
# ...

# %%
df_test['pred'].value_counts()
# Out:
# 2.0    3074
# 4.0     859
# Name: pred, dtype: int64

# %%
df_gr['pred_label'].value_counts()
# Out:
# 2    76
# 3    41
# Name: pred_label, dtype: int64

# %%
df_gr['pred_label_3label'].value_counts()
# Out:
# 2    76
# 3    41
# Name: pred_label_3label, dtype: int64

# %%
df_gr['target'].value_counts()
# Out:
# 3    43
# 2    38
# 1    29
# 4     6
# 0     1
# Name: target, dtype: int64
