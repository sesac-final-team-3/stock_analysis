# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install git+https://git@github.com/SKTBrain/KoBERT.git@master
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://****@github.com/SKTBrain/KoBERT.git@master
#   Cloning https://****@github.com/SKTBrain/KoBERT.git (to revision master) to /tmp/pip-req-build-r_q6yod0
#   Running command git clone --filter=blob:none --quiet 'https://****@github.com/SKTBrain/KoBERT.git' /tmp/pip-req-build-r_q6yod0
#   Resolved https://****@github.com/SKTBrain/KoBERT.git to commit 47a69af87928fc24e20f571fe10c3cc9dd9af9a3
#   Preparing metadata (setup.py) ... done
# Collecting boto3<=1.15.18
#   Downloading boto3-1.15.18-py2.py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 KB 4.9 MB/s eta 0:00:00
# Collecting gluonnlp<=0.10.0,>=0.6.0
#   Downloading gluonnlp-0.10.0.tar.gz (344 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.5/344.5 KB 16.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting mxnet<=1.7.0.post2,>=1.4.0
#   Downloading mxnet-1.7.0.post2-py2.py3-none-manylinux2014_x86_64.whl (54.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 MB 29.9 MB/s eta 0:00:00
# Collecting onnxruntime<=1.8.0,==1.8.0
#   Downloading onnxruntime-1.8.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 101.3 MB/s eta 0:00:00
# Collecting sentencepiece<=0.1.96,>=0.1.6
#   Downloading sentencepiece-0.1.96-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 70.5 MB/s eta 0:00:00
# Collecting torch<=1.10.1,>=1.7.0
#   Downloading torch-1.10.1-cp38-cp38-manylinux1_x86_64.whl (881.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 881.9/881.9 MB 175.0 MB/s eta 0:00:01tcmalloc: large alloc 1102397440 bytes == 0x37c5c000 @  0x7f615a316615 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x5d8868 0x4997a2 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.9/881.9 MB 1.8 MB/s eta 0:00:00
# Collecting transformers<=4.8.1,>=4.8.1
#   Downloading transformers-4.8.1-py3-none-any.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 61.7 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.8/dist-packages (from onnxruntime<=1.8.0,==1.8.0->kobert==0.2.3) (1.12)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.8/dist-packages (from onnxruntime<=1.8.0,==1.8.0->kobert==0.2.3) (3.19.6)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.8/dist-packages (from onnxruntime<=1.8.0,==1.8.0->kobert==0.2.3) (1.21.6)
# Collecting botocore<1.19.0,>=1.18.18
#   Downloading botocore-1.18.18-py2.py3-none-any.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 85.7 MB/s eta 0:00:00
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading s3transfer-0.3.7-py2.py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 KB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: cython in /usr/local/lib/python3.8/dist-packages (from gluonnlp<=0.10.0,>=0.6.0->kobert==0.2.3) (0.29.32)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from gluonnlp<=0.10.0,>=0.6.0->kobert==0.2.3) (21.3)
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: requests<3,>=2.20.0 in /usr/local/lib/python3.8/dist-packages (from mxnet<=1.7.0.post2,>=1.4.0->kobert==0.2.3) (2.25.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch<=1.10.1,>=1.7.0->kobert==0.2.3) (4.4.0)
# Collecting huggingface-hub==0.0.12
#   Downloading huggingface_hub-0.0.12-py3-none-any.whl (37 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from transformers<=4.8.1,>=4.8.1->kobert==0.2.3) (6.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 KB 34.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers<=4.8.1,>=4.8.1->kobert==0.2.3) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers<=4.8.1,>=4.8.1->kobert==0.2.3) (3.8.2)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 77.5 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers<=4.8.1,>=4.8.1->kobert==0.2.3) (2022.6.2)
# Requirement already satisfied: urllib3<1.26,>=1.20 in /usr/local/lib/python3.8/dist-packages (from botocore<1.19.0,>=1.18.18->boto3<=1.15.18->kobert==0.2.3) (1.24.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.8/dist-packages (from botocore<1.19.0,>=1.18.18->boto3<=1.15.18->kobert==0.2.3) (2.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->gluonnlp<=0.10.0,>=0.6.0->kobert==0.2.3) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.20.0->mxnet<=1.7.0.post2,>=1.4.0->kobert==0.2.3) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.20.0->mxnet<=1.7.0.post2,>=1.4.0->kobert==0.2.3) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.20.0->mxnet<=1.7.0.post2,>=1.4.0->kobert==0.2.3) (4.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers<=4.8.1,>=4.8.1->kobert==0.2.3) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers<=4.8.1,>=4.8.1->kobert==0.2.3) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers<=4.8.1,>=4.8.1->kobert==0.2.3) (1.2.0)
# Building wheels for collected packages: kobert, gluonnlp, sacremoses
#   Building wheel for kobert (setup.py) ... done
#   Created wheel for kobert: filename=kobert-0.2.3-py3-none-any.whl size=15708 sha256=68f5bdc1319656a9292865133ba193b2291f1b4489704e070b33899415a012e0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-42zs32y9/wheels/bf/5f/74/81bf3a1332130eb6629ecf58876a8746b77021e7d7b0638e91
#   Building wheel for gluonnlp (setup.py) ... done
#   Created wheel for gluonnlp: filename=gluonnlp-0.10.0-cp38-cp38-linux_x86_64.whl size=619631 sha256=e1ec7db6fc7342b4682aab4f7fcc23ce6ba640abc0cf35fc80d20c8c85557f6c
#   Stored in directory: /root/.cache/pip/wheels/b6/93/9d/2237550c409eb3ed725d6302b7897ddd9a037b40cef66dcd9c
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=5b72b8b8e790908a3206affa009725edd7bc5eed49d760328a316cf8392482d9
#   Stored in directory: /root/.cache/pip/wheels/82/ab/9b/c15899bf659ba74f623ac776e861cf2eb8608c1825ddec66a4
# Successfully built kobert gluonnlp sacremoses
# Installing collected packages: tokenizers, sentencepiece, torch, sacremoses, onnxruntime, jmespath, graphviz, mxnet, huggingface-hub, gluonnlp, botocore, transformers, s3transfer, boto3, kobert
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.0+cu116
#     Uninstalling torch-1.13.0+cu116:
#       Successfully uninstalled torch-1.13.0+cu116
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.14.0+cu116 requires torch==1.13.0, but you have torch 1.10.1 which is incompatible.
# torchtext 0.14.0 requires torch==1.13.0, but you have torch 1.10.1 which is incompatible.
# torchaudio 0.13.0+cu116 requires torch==1.13.0, but you have torch 1.10.1 which is incompatible.
# Successfully installed boto3-1.15.18 botocore-1.18.18 gluonnlp-0.10.0 graphviz-0.8.4 huggingface-hub-0.0.12 jmespath-0.10.0 kobert-0.2.3 mxnet-1.7.0.post2 onnxruntime-1.8.0 s3transfer-0.3.7 sacremoses-0.0.53 sentencepiece-0.1.96 tokenizers-0.10.3 torch-1.10.1 transformers-4.8.1

# %%
# gpu 프리미엄 사용 시
# !pip3 install torch==1.9.0+cu111 torchvision==0.10.0+cu111 torchaudio==0.9.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.9.0+cu111
#   Downloading https://download.pytorch.org/whl/cu111/torch-1.9.0%2Bcu111-cp38-cp38-linux_x86_64.whl (2041.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 2.0/2.0 GB 89.9 MB/s eta 0:00:01tcmalloc: large alloc 2041339904 bytes == 0x2252000 @  0x7ff550ddf1e7 0x4d30a0 0x4d312c 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x5d8868 0x4997a2 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x4997a2
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 2.0/2.0 GB 88.8 MB/s eta 0:00:01tcmalloc: large alloc 2551676928 bytes == 0x7bd18000 @  0x7ff550de0615 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x5d8868 0x4997a2 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941
# tcmalloc: large alloc 2041339904 bytes == 0x2252000 @  0x7ff550ddf1e7 0x4d30a0 0x5dede2 0x6758aa 0x4f750a 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4fe318 0x5da092 0x62042c 0x5d8d8c 0x561f80 0x4fd2db 0x4997c7 0x4fd8b5 0x4997c7 0x4fd8b5 0x49abe4 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x5d8868 0x5da092 0x587116
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 GB 917.8 kB/s eta 0:00:00
# Collecting torchvision==0.10.0+cu111
#   Downloading https://download.pytorch.org/whl/cu111/torchvision-0.10.0%2Bcu111-cp38-cp38-linux_x86_64.whl (23.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 41.8 MB/s eta 0:00:00
# Collecting torchaudio==0.9.0
#   Downloading torchaudio-0.9.0-cp38-cp38-manylinux1_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 21.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.9.0+cu111) (4.4.0)
# Requirement already satisfied: pillow>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision==0.10.0+cu111) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchvision==0.10.0+cu111) (1.21.6)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.1
#     Uninstalling torch-1.10.1:
#       Successfully uninstalled torch-1.10.1
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.0+cu116
#     Uninstalling torchvision-0.14.0+cu116:
#       Successfully uninstalled torchvision-0.14.0+cu116
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.13.0+cu116
#     Uninstalling torchaudio-0.13.0+cu116:
#       Successfully uninstalled torchaudio-0.13.0+cu116
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.14.0 requires torch==1.13.0, but you have torch 1.9.0+cu111 which is incompatible.
# Successfully installed torch-1.9.0+cu111 torchaudio-0.9.0 torchvision-0.10.0+cu111

# %%
import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import gluonnlp as nlp
import numpy as np
from tqdm import tqdm, tqdm_notebook

from sklearn.model_selection import train_test_split

from kobert.utils import get_tokenizer
from kobert.pytorch_kobert import get_pytorch_kobert_model

from transformers import AdamW
from transformers.optimization import get_cosine_schedule_with_warmup
import pandas as pd
from tqdm.notebook import tqdm

import re

# %%
##GPU 사용 시
device = torch.device("cuda:0")

bertmodel, vocab = get_pytorch_kobert_model()

from transformers import AutoTokenizer, AutoModelForSequenceClassification

# tokenizer = AutoTokenizer.from_pretrained("snunlp/KR-FinBert-SC")

# model = AutoModelForSequenceClassification.from_pretrained("snunlp/KR-FinBert-SC")
# Out:
# /content/.cache/kobert_v1.zip[██████████████████████████████████████████████████]
# /content/.cache/kobert_news_wiki_ko_cased-1087f8699e.spiece[██████████████████████████████████████████████████]

# %% [markdown]
# ### 데이터 전처리

# %%
import pandas as pd

# %% [markdown]
# # 데이터 입력

# %%
df_sent = pd.read_csv('/content/drive/MyDrive/뉴스원인분석_modeling/data/LG에너지솔루션_tagging_sent_0104.csv')
df_sent
# Out:
#               date                                               sent  label  \
# 0       2022-01-28  증시자금 블랙홀 엔솔에 코스피 시총 69조원 증발서울연합뉴스 이미령 기자  공모주 ...      0
# 1       2022-01-28  27일 한국거래소에 따르면 이날 유가증권시장 시가총액은 총 2천56조8천억원으로 전...      0
# 2       2022-01-28  다만 이는 이날 상장한 에너지솔루션 시가총액118조2천억원이 더해진 규모로, 에너지...      0
# 3       2022-01-28    이날 코스피가 3.50 급락하며 2,610대로 밀려난 것도 이런 이유에서란 분석이다.      0
# 4       2022-01-28  서상영 미래에셋증권 연구원은 이날 코스피 하락 요인 중 가장 큰 건 에너지솔루션 수...      0
# ...            ...                                                ...    ...
# 125904  2022-11-30                        업계에서는 분할 공포증 영향이라는 해석도 나온다.      4
# 125905  2022-11-30  화학의 에너지솔루션 물적 분할 이후 분할악재라는 인식 때문에 주가가 내리는 것이라는...      4
# 125906  2022-11-30  한 투자 업계 고위 임원은 기존 사업이 돈을 벌고 신사업에 투자하다 신사업이 자생력...      4
# 125907  2022-11-30  다만 주가가 지나치게 급락했다는 점에서 외부로 알려지지 않은 내용이 더 있는 것 아...      4
# 125908  2022-11-30  한 투자 업계 관계자는 주가가 급락하는 배경이 있을 수도 있다며 장 상황이 안 좋다...      4
#
#         news_id  targetpm
# 0             0         1
# 1             0         1
# 2             0         1
# 3             0         1
# 4             0         1
# ...         ...       ...
# 125904     5952         3
# 125905     5952         3
# 125906     5952         3
# 125907     5952         3
# 125908     5952         3
#
# [125909 rows x 5 columns]

# %%
# 셔플
df_sent = df_sent.sample(frac=1).reset_index(drop=True)
df_sent
# Out:
#               date                                               sent  label  \
# 0       2022-02-10                           이모빌리티솔루션은 비상장법인으로 남게 된다.      0
# 1       2022-07-29         장 초반 2,463.05까지 치솟기도 했으나 이후 상승 폭을 일부 축소했다.      3
# 2       2022-03-18                       환율 움직임도 국내 증시에 우호적으로 흐르고 있다.      3
# 3       2022-06-23  이번 사절단은 무역협회를 중심으로 현대자동차, , 하이닉스, 세아제강, 엑시콘 등 ...      2
# 4       2022-10-19  이날 국내 증시가 미국과 상반된 움직임을 보이고 있는 것은 기업 실적 때문으로 풀이된다.      3
# ...            ...                                                ...    ...
# 125904  2022-07-27  최재헌 위원은 현대자동차와 기아의 제품 포트폴리오에 따라 고가 차종에 부품을 공급하...      2
# 125905  2022-03-14  이어 화학이 2 이상 밀렸고 운송장비, 비금속광물, 유통업, 음식료품, 제조업 등이...      0
# 125906  2022-02-18      와 주관사단은 예비심사 신청서 승인을 받는 대로 곧장 공모 수순을 밟을 계획이다.      2
# 125907  2022-04-26                        프로그램 매매는 946억원 매도 우위를 나타냈다.      1
# 125908  2022-08-12  한국자동차산업협회도 인플레이션 감축법 중 전기차 세제혜택에 대한 의견서를 지난 10...      1
#
#         news_id  targetpm
# 0           423         1
# 1          3790         3
# 2          1216         3
# 3          2978         1
# 4          5172         3
# ...         ...       ...
# 125904     3717         1
# 125905     1090         1
# 125906      636         3
# 125907     1965         1
# 125908     4018         1
#
# [125909 rows x 5 columns]

# %%
df_gr = df_sent.groupby('date')[['label']].mean()
# 날짜별로 train_test_split
train_date, test_date = train_test_split(df_gr, test_size=0.1, random_state=2022, stratify=df_gr['label'])
train_date_list = train_date.index
test_date_list = test_date.index
train_data = df_sent[df_sent['date'].isin(train_date_list)][['date','sent', 'label','targetpm','news_id']]
test_data = df_sent[df_sent['date'].isin(test_date_list)][['date','sent', 'label','targetpm','news_id']]
train_data.shape, test_data.shape
# Out:
# ((113187, 5), (12722, 5))

# %%
df_sent['label'].value_counts()
# Out:
# 2    31128
# 3    30389
# 1    26282
# 0    19764
# 4    18346
# Name: label, dtype: int64

# %%
tokenizer = get_tokenizer()
tok = nlp.data.BERTSPTokenizer(tokenizer, vocab, lower=False)
# Out:
# using cached model. /content/.cache/kobert_news_wiki_ko_cased-1087f8699e.spiece

# %%
class BERTDataset(Dataset):
    def __init__(self, dataset, sent_idx, label_idx, bert_tokenizer, max_len,
                 pad, pair):
        transform = nlp.data.BERTSentenceTransform(
            bert_tokenizer, max_seq_length=max_len, pad=pad, pair=pair) 

        self.sentences = [transform([i[sent_idx]]) for i in dataset]
        self.labels = [np.int32(i[label_idx]) for i in dataset]

    def __getitem__(self, i):
        return (self.sentences[i] + (self.labels[i], ))

    def __len__(self):
        return (len(self.labels))

# %%
max_len = 128 # 해당 길이를 초과하는 단어에 대해선 bert가 학습하지 않음
batch_size = 64
warmup_ratio = 0.1
num_epochs = 50
max_grad_norm = 1
log_interval = 200
learning_rate = 5e-5

# %%
class BERTClassifier(nn.Module):
    def __init__(self,
                 bert,
                 hidden_size = 768,
                 num_classes = 5, # softmax 사용 <- binary일 경우는 2
                 dr_rate=None,
                 params=None):
        super(BERTClassifier, self).__init__()
        self.bert = bert
        self.dr_rate = dr_rate
                 
        self.classifier = nn.Linear(hidden_size , num_classes)
        if dr_rate:
            self.dropout = nn.Dropout(p=dr_rate)
    
    def gen_attention_mask(self, token_ids, valid_length):
        attention_mask = torch.zeros_like(token_ids)
        for i, v in enumerate(valid_length):
            attention_mask[i][:v] = 1
        return attention_mask.float()

    def forward(self, token_ids, valid_length, segment_ids):
        attention_mask = self.gen_attention_mask(token_ids, valid_length)
        
        _, pooler = self.bert(input_ids = token_ids, token_type_ids = segment_ids.long(), attention_mask = attention_mask.float().to(token_ids.device))
        if self.dr_rate:
            out = self.dropout(pooler)
        return self.classifier(out)

# %%
model = BERTClassifier(bertmodel,  dr_rate=0.5).to(device)

# %%
# 학습 평가 지표인 accuracy 계산 -> 얼마나 타겟값을 많이 맞추었는가
def calc_accuracy(X,Y):
    max_vals, max_indices = torch.max(X, 1)
    train_acc = (max_indices == Y).sum().data.cpu().numpy()/max_indices.size()[0]
    return train_acc

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
model = torch.load("/content/drive/MyDrive/뉴스원인분석_modeling/model/KoBERT_lgenergy_model_mxl128_bt128_sentmodel_sample10000_ep30_tagging0104.pt")
model.eval()
# Out:
# BERTClassifier(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(8002, 768, padding_idx=1)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (classifier): Linear(in_features=768, out_features=5, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
test_data
# Out:
#               date                                               sent  label  \
# 11      2022-03-21                              공매도의 공은 한자로 빌 공을 씁니다.      3
# 27      2022-03-31  제조 공정도 글로벌 최고 수준 전자 스마트파크, 세계경제포럼 등대공장 선정헤럴드경제...      2
# 36      2022-07-21                                    시총상위주는 상승 우위였다.      3
# 56      2022-02-28  이달 28일 한국자원정보서비스에 따르면 순도 99 탄산리튬 가격은 25일 기준 킬로...      1
# 67      2022-02-28    전자는 2013년부터 협력사가 기술자료를 임치할 때 드는 비용을 전액 지원하고 있다.      1
# ...            ...                                                ...    ...
# 125888  2022-06-30                   외국인과 기관 투자가들의 매도세가 지수를 끌어내리고 있다.      0
# 125893  2022-06-15                      1.94, 1.21 등 반도체 주는 주가가 떨어졌다.      1
# 125895  2022-08-11                           한편 개인은 1118억 원을 순매도 중이다.      4
# 125901  2022-05-09  구 회장은 축사에서 코리아가 이곳 군포 공장에서 생산하는 전기차 부품 등은 가 강점...      1
# 125902  2022-03-21                                 80개 종목은 보합권에 머물렀다.      3
#
#         targetpm  news_id
# 11             3     1247
# 27             3     1482
# 36             3     3556
# 56             1      863
# 67             1      861
# ...          ...      ...
# 125888         1     3138
# 125893         1     2846
# 125895         3     3982
# 125901         1     2166
# 125902         3     1258
#
# [12722 rows x 5 columns]

# %%
# batch_size 수정 코드
batch_size = 128

test_data3 = test_data.copy()
test_data3 = test_data3.reset_index(drop=True )
test_data3['pred'] = ''

model.eval()
unseen_values = test_data3[['sent', 'label']].values
test_set = BERTDataset(unseen_values, 0, 1, tok, max_len, True, False)
test_input = torch.utils.data.DataLoader(test_set, batch_size=batch_size, num_workers=5)
for batch_id, (token_ids, valid_length, segment_ids, label) in tqdm(enumerate(test_input)):
  token_ids = token_ids.long().to(device)
  segment_ids = segment_ids.long().to(device)
  valid_length= valid_length
  out = model(token_ids, valid_length, segment_ids)
  for outn in range(len(out)) :
    pred = int(out[outn].argmax().cpu().numpy())
    idx = batch_size * batch_id + outn
    test_data3.iloc[idx, -1] = pred
    if idx % 5000 == 0 :
      print(idx, pred)
test_data3.head(20)
# Out:
# 0it [00:00, ?it/s]
# 0 4
# 5000 2
# 10000 3
#           date                                               sent  label  \
# 0   2022-03-21                              공매도의 공은 한자로 빌 공을 씁니다.      3
# 1   2022-03-31  제조 공정도 글로벌 최고 수준 전자 스마트파크, 세계경제포럼 등대공장 선정헤럴드경제...      2
# 2   2022-07-21                                    시총상위주는 상승 우위였다.      3
# 3   2022-02-28  이달 28일 한국자원정보서비스에 따르면 순도 99 탄산리튬 가격은 25일 기준 킬로...      1
# 4   2022-02-28    전자는 2013년부터 협력사가 기술자료를 임치할 때 드는 비용을 전액 지원하고 있다.      1
# 5   2022-07-26                      이와 달리 네이버035420는 2 넘게 하락 중이다.      3
# 6   2022-10-07    이는 증권가가 추정한 영업이익 전망치 4060억원에프앤가이드 기준을 웃도는 수준이다.      3
# 7   2022-06-24         에너지솔루션373220과 삼성바이오로직스207940도 1 미만 오르고 있다.      3
# 8   2022-07-26                        화학은 에너지솔루션의 지분율은 81.84나 된다.      3
# 9   2022-10-26             반면 섬유의복, 비금속광물, 서비스, 보험 등은 1대 하락세를 탔다.      4
# 10  2022-06-24  닷컴의 모회사인 이마트 역시 연초 대비 약 30 하락하며 지난 2020년 신종 코로...      3
# 11  2022-02-28  상장주식은 대주주가 아니면 양도세가 없지만 비상장주식은 매수매도에서 얻어지는 모든 ...      1
# 12  2022-07-26                     수탁수수료는 부문 외에 기관영업부문 실적에도 반영된다.      3
# 13  2022-02-16          전날 급락했던 의료정밀2.28, 의약품1.92 등도 1 넘게 반등 중이다.      3
# 14  2022-10-26                   특히 미국 국채금리가 떨어지면서 주식 투자 심리를 키웠다.      4
# 15  2022-08-16          같은 시간 코스닥지수는 전장보다 1.61포인트0.19 오른 833.24다.      2
# 16  2022-05-09                라이온하트가 상장하면 카카오게임즈의 주가는 악영향이 불가피하다.      1
# 17  2022-06-20      이 부회장이 네덜란드  본사를 찾은 것은 2020년 10월 이후 20개월 만이다.      0
# 18  2022-07-21  정유업계는 올해 상반기 국제유가 급등과 핵심 수익성 지표인 정제마진 강세로 역대급 ...      3
# 19  2022-02-28  이노베이션은 대전 소재 폐배터리 재활용 데모 플랜트시험 설비의 기계적 준공을 지난해...      1
#
#     targetpm  news_id pred
# 0          3     1247    4
# 1          3     1482    1
# 2          3     3556    0
# 3          1      863    3
# 4          1      861    0
# 5          3     3664    2
# 6          3     4990    2
# 7          3     2998    3
# 8          3     3670    3
# 9          3     5285    4
# 10         3     2991    2
# 11         1      846    0
# 12         3     3641    2
# 13         3      589    1
# 14         3     5278    3
# 15         3     4049    2
# 16         1     2162    4
# 17         1     2898    3
# 18         3     3557    2
# 19         1      849    3

# %%
# 뉴스별 라벨링
# 뉴스 빈도 + 날 빈도
test_data4 = test_data.copy()
test_data4['pred'] = test_data3['pred'].values 
test_data4['pred'] = test_data4['pred'].astype('int')
df_news = test_data4.groupby('news_id')[['label', 'pred', 'targetpm']].mean()
df_news_idx = df_news.index
# 뉴스 라벨 빈도수 계산
for idx in df_news_idx:
  df_news.loc[idx, 'cnt_pred'] = int(test_data4[test_data4['news_id'] == idx ]['pred'].value_counts().idxmax())
  # print(idx, df_news.loc[idx, 'cnt_pred'])
  
# 뉴스별 값 태깅
test_data4['news_cnt'] = -1
for idx_nm in range(len(test_data4)) :
  news_idx = test_data4.iloc[idx_nm, 4]
  test_data4.iloc[idx_nm, -1] = df_news.loc[news_idx, 'cnt_pred']

df_gr = test_data4.groupby('date')[['label', 'news_cnt', 'targetpm']].mean()
df_date = df_gr.index
for idx in df_date:
  df_gr.loc[idx, 'cnt_pred'] = int(test_data4[test_data4['date'] == idx ]['news_cnt'].value_counts().idxmax())

df_gr['pred_label'] = df_gr['cnt_pred'].apply(lambda x : int(np.round(x)))
df_gr['pred_pm'] = df_gr['pred_label'].apply(lambda x: 1 if x< 2 else 3)





df_gr = df_gr.reset_index()
for idx in df_gr.index :
  if df_gr.loc[idx, 'label'] == df_gr.loc[idx, 'pred_label']:
    temp_eval = True
  else :
    temp_eval = False
  df_gr.loc[idx, 'eval_5'] = temp_eval

for idx in df_gr.index :
  if df_gr.loc[idx, 'label'] == 0 :
    df_gr.loc[idx, 'target_3label'] = 1
  elif df_gr.loc[idx, 'label'] == 4 :
    df_gr.loc[idx, 'target_3label'] = 3
  else :
    df_gr.loc[idx, 'target_3label'] = int(df_gr.loc[idx, 'label'])

  if df_gr.loc[idx, 'pred_label'] == 0 :
    df_gr.loc[idx, 'pred_label_3label'] = 1
  elif df_gr.loc[idx, 'pred_label'] == 4 :
    df_gr.loc[idx, 'pred_label_3label'] = 3
  else :
    df_gr.loc[idx, 'pred_label_3label'] = int(df_gr.loc[idx, 'pred_label'])

df_gr['pred_label_3label'] = df_gr['pred_label_3label'].apply(lambda x : int(x))

for idx in df_gr.index :
  if df_gr.loc[idx, 'target_3label'] == df_gr.loc[idx, 'pred_label_3label']:
    temp_eval = True
  else :
    temp_eval = False
  df_gr.loc[idx, 'eval_3'] = temp_eval

for idx in df_gr.index :
  if df_gr.loc[idx, 'targetpm'] == df_gr.loc[idx, 'pred_pm']:
    temp_eval = True
  else :
    temp_eval = False
  df_gr.loc[idx, 'eval_pm'] = temp_eval



print('5중분류 정확도 :', round(df_gr['eval_5'].sum() / len(df_gr), 2), '\n')
print('3중분류 정확도 :', round(df_gr['eval_3'].sum() / len(df_gr), 2), '\n')
print('이진분류 정확도 :', round(df_gr['eval_pm'].sum() / len(df_gr), 2), '\n')

df_gr.head()
# Out:
# 5중분류 정확도 : 0.33
#
# 3중분류 정확도 : 0.48
#
# 이진분류 정확도 : 0.62
#          date  label  news_cnt  targetpm  cnt_pred  cnt_pred_mean  pred_label  \
# 0  2022-02-16    3.0  1.628966       3.0       2.0            1.0           2
# 1  2022-02-28    1.0  1.643750       1.0       0.0            1.0           0
# 2  2022-03-21    3.0  2.067639       3.0       2.0            2.0           2
# 3  2022-03-30    2.0  2.179426       1.0       3.0            2.0           3
# 4  2022-03-31    2.0  1.751620       3.0       0.0            1.0           0
#
#    pred_pm eval_5  target_3label  pred_label_3label eval_3 eval_pm
# 0        3  False            3.0                  2  False    True
# 1        1  False            1.0                  1   True    True
# 2        3  False            3.0                  2  False    True
# 3        3  False            2.0                  3  False   False
# 4        1  False            2.0                  1  False   False

# %%
test_data3['pred'].value_counts()
# Out:
# 2    3700
# 0    2850
# 3    2734
# 1    1968
# 4    1470
# Name: pred, dtype: int64

# %%
df_gr['pred_label'].value_counts()
# Out:
# 2    11
# 3     6
# 0     4
# Name: pred_label, dtype: int64

# %%
df_gr['label'].value_counts()
# Out:
# 3.0    6
# 2.0    6
# 1.0    4
# 0.0    3
# 4.0    2
# Name: label, dtype: int64

# %%
df_gr['cnt_pred'].mean()
# Out:
# 1.9047619047619047

# %%
df_gr['eval_pm'].value_counts(normalize=True)
# Out:
# True     0.761905
# False    0.238095
# Name: eval_pm, dtype: float64

# %%
df_news['cnt_pred'].value_counts()
# Out:
# 2.0    209
# 3.0    147
# 0.0    122
# 1.0     56
# 4.0     48
# Name: cnt_pred, dtype: int64

# %%
df_gr['target'].value_counts()
# Out:
# 3    43
# 2    38
# 1    29
# 4     6
# 0     1
# Name: target, dtype: int64
